# %%
import pandas as pd
from pathlib import Path

# %%
csv = Path('clean_data/clean_firearms.csv')
firearms_df = pd.read_csv(csv)
firearms_df.head(3)
# Out:
#   Case # Shooter Last Name Shooter First Name  Full Date  \
# 0      1           Whitman            Charles  1/08/1966
# 1      1           Whitman            Charles  1/08/1966
# 2      1           Whitman            Charles  1/08/1966
#
#                                       Make and Model Classification Caliber  \
# 0                Remington 700 6mm bolt-action rifle          Rifle   Small
# 1  Remington .35-caliber Model 141 pump-action rifle          Rifle  Medium
# 2                                     .30 M1 carbine          Rifle  Medium
#
#   Used in Shooting?     Modified Large Capacity Magazine Extended Magazine  \
# 0               Yes  No evidence             No evidence       No evidence
# 1       No evidence  No evidence             No evidence       No evidence
# 2               Yes  No evidence                     Yes       No evidence
#
#      When Obtained                    Legal Purchase Illegal Purchase  \
# 0  > 1 month prior                           Unknown          Unknown
# 1  < 1 month prior  Federal Firearms Licensed dealer            Legal
# 2  < 1 month prior  Federal Firearms Licensed dealer            Legal
#
#   Assembled with Legal Parts   Gifted    Theft Unknown
# 0                    Unknown  Unknown  Unknown     Yes
# 1                         No       No       No      No
# 2                         No       No       No      No

# %% [markdown]
# ## When are the guns procured?

# %%
total_firearms = firearms_df['When Obtained'].count()

timeframe_df = pd.DataFrame(firearms_df['When Obtained'].value_counts())
timeframe_df['Percentage'] = 100*timeframe_df['When Obtained']/total_firearms

timeframe_df
# Out:
#                  When Obtained  Percentage
# > 1 month prior            214   51.815981
# Unknown                    103   24.939467
# < 1 month prior             96   23.244552

# %% [markdown]
# ## Are the guns procured legally?

# %%
total_firearms = firearms_df['Legal Purchase'].count()

firearms_df['Legal Purchase'].value_counts()
# Out:
# Unknown                              147
# Federal Firearms Licensed dealer     138
# Legal but specific source unknown     62
# Illegal                               54
# Unregulated private sale              12
# Name: Legal Purchase, dtype: int64

# %%
138+62
# Out:
# 200

# %%
firearms_df['Illegal Purchase'].value_counts()
# Out:
# Legal                                  209
# Unknown                                150
# Illegal but specific source unknown     14
# System failure                          12
# Lying and buying                        10
# Straw purchas                            7
# Legal sale but illegal possession        7
# Illegal street sale                      4
# Name: Illegal Purchase, dtype: int64

# %%
14+12+10+7+7+4
# Out:
# 54

# %%
firearms_df['Unknown'].value_counts()
# Out:
# No     317
# Yes     96
# Name: Unknown, dtype: int64

# %%
total_firearms
# Out:
# 413

# %% [markdown]
# ## Guns that are likely to be used

# %%
guns_types_df = firearms_df[:]

# %%
import warnings
warnings.simplefilter(action='ignore')

guns_types_df['Firearm Type'] = guns_types_df['Caliber'] + '-caliber ' + guns_types_df['Classification']
guns_types_df['Firearm Type'].value_counts()
# Out:
# Medium-caliber Handgun            134
# Large-caliber Handgun              47
# Small-caliber Assault weapon       47
# Large-caliber Shotgun              44
# Medium-caliber Assault weapon      36
# Unknown-caliber Handgun            25
# Small-caliber Handgun              22
# Medium-caliber Rifle               20
# Small-caliber Rifle                19
# Large-caliber Rifle                 6
# Unknown-caliber Assault weapon      5
# Large-caliber Assault weapon        3
# Small-caliber Unknown               2
# Unknown-caliber Rifle               1
# Unknown-caliber Unknown             1
# Medium-caliber Shotgun              1
# Name: Firearm Type, dtype: int64

# %%
guns_count_df = pd.DataFrame(firearms_df['Make and Model'].value_counts())

gun_names = guns_count_df.index
len(gun_names)

for g in gun_names:
    print(g)
# Out:
# Handgun
# Shotgun
# 9mm Glock 19 pistol
# semi-automatic pistol
# .45-caliber pistol
# 12-gauge shotgun
# 9mm Glock pistol
# .38-caliber revolver
# 9mm handgun
# 9mm pistol
# 9mm Glock 17 pistol
# .22-caliber rifle
# AR-15-style rifle
# .40-caliber Glock pistol
# 12-gauge pump-action shotgun
# .32-caliber revolver
# 9 mm pistol
# Pistol
# 9mm semi-automatic pistol
# Glock .357 pistol
# .38-caliber Charter Arms revolver
# .22-caliber pistol
# .45-caliber Glock 21 pistol
# 9mm SIG Sauer P226R pistol
# .40-caliber Smith & Wesson handgun
# AR-15 style semi-automatic rifle assembled from parts
# .380-caliber Intratec MAC-11 semi-automatic machine pistol
# .45-caliber Glock pistol
# .357-caliber Magnum Smith & Wesson revolver
# .308-caliber Daniel Defense DD5V1 AR-10 with bipod, scope
# 9mm Glock semi-automatic pistol
# .223-caliber Ruger Mini-14 rifle
# 9mm Intratec Tec-DC9 semi-automatic machine pistol
# .40-caliber Smith & Wesson semi-automatic pistol
# Smith & Wesson pistol
# .25-caliber semi-automatic pistol
# .22-caliber AR-7 automatic rifle with sawed-off barrel
# .38-caliber Smith & Wesson revolver
# Unknown
# AR-15 style rifle
# 9mm Beretta pistol
# .223-caliber Smith & Wesson M&P15 AR-15 style rifle
# .357 Magnum Smith & Wesson revolver
# 9mm Springfield Armory pistol
# 12-gauge Remington 870 Express sawed-off shotgun
# .223-caliber AR-15 style semi-automatic rifle assembled from parts
# Mossberg 500 shotgun with pistol grip
# .44-caliber antique black powder pistol modified to shoot .45-caliber bullets
# 9mm Smith & Wesson pistol
# 9mm Beretta semi-automatic pistol
# 9mm Glock 34 Long Slide pistol
# .40-caliber Beretta PX4 Storm pistol
# .380-caliber HiPoint pistol
# .45-caliber Glock 41 pistol
# 7.62mm AK-47 style semi-automatic rifle
# .38-caliber Smith & Wesson M624-2 revolver
# 12-gauge Saiga 12 semi-automatic shotgun with pistol grip
# .40-caliber Taurus PT24/7 pistol
# 5.56x45mm Del-Ton DTI15 AR-15 style rifle
# .40-caliber Smith & Wesson 99 pistol
# Remington 700 6mm bolt-action rifle
# .40-caliber Taurus pistol
# .45-caliber Hi-Point pistol
# 5.7mm FN Herstal Five-seveN pistol with laser sight
# High-powered assault rifle
# .45-caliber Beretta PX4 Storm pistol
# 9mm Beretta 92FS pistol with laser sight
# .22-caliber handgun
# Winchester 1300 pump-action shotgun
# Winchester lever-action rifle
# .380-caliber Hi-Point CF380 pistol
# 12-gauge Izhmash Saiga semi-automatic shotgun
# 12-gauge Remington Sportsman 48 sawed-off shotgun
# 9mm short Kurz SIG Sauer P232 pistol
# .44-caliber Magnum Smith & Wesson revolver
# AK-47 rifle
# Bushmaster XM15 AR-15 style rifle modified to shoot a 6.8mm round
# .40-caliber Beretta pistol
# 7.62mm WASR-10 Century Arms AK-47 style semi-automatic rifle
# .38-caliber Smith & Wesson double action revolver
# 9mm Davis Industries handgun
# 9mm Ruger SR9 pistol
# 9mm Ruger P95 pistol
# .22-caliber Savage Mark II bolt-action rifle
# 9mm SIG Sauer P226 pistol
# 10mm Glock 20 pistol
# 5.56mm Bushmaster XM15-E2S AR-15 style semi-automatic rifle
# 9mm Springfield Armory XDM pistol
# .223 Smith & Wesson M&P15 AR-15 style rifle
# 9mm Springfield pistol
# .45-caliber Heckler & Koch pistol
# .44 Magnum Smith & Wesson revolver
# .38-caliber Colt Agent revolver
# 9mm Glock 26
# 7.62mm Romarm GP-WASR-10 semi-automatic rifle
# 7.62mm Norinco MAK-90 AK-47 style rifle modified to full automatic
# .357 Magnum six-shot revolver
# .45-caliber Hi-Point ACP pistol
# 12-gauge pump-action Remington 870 shotgun
# Saiga AK-74 assault rifle with red dot optic
# .223-caliber DPMS A-15 AR-15 style rifle
# 12-gauge Mossberg shotgun
# 9 mm handgun
# .45-caliber Glock 21 semi-automatic handgun
# 7.62-caliber SKS rifle
# Handgun with silencer
# .22-caliber Ruger Mark IV pistol with homemade silencer
# 9mm Ruger semi-automatic pistol
# .223-caliber AR-15 style rifle
# 12-gauge Remington 870 short-barreled shotgun
# .223-caliber Anderson AM-15 pistol modified to function like an AR-15 rifle
# 7.62mm WASR-10 AK-47 style rifle
# .45-caliber Glock 21 pistol with sound suppressor
# Colt AR-15 semi-automatic rifle
# .50-caliber Smith & Wesson 500 revolver
# 12-gauge Mossberg pump-action shotgun
# Ruger AR-556 semi-automatic pistol
# Glock semi-automatic handgun
# Ruger AR-556
# HM Defense HM15F
# 9mm Sig Sauer
# semi-automatic rifle
# Bushmaster XM-15 rifle
# Mossberg 500 shotgun
# Savage Axis XP rifle
# DDM4 rifle
# Smith & Wesson M&P15 semi-automatic rifle
# "ghost gun" rifle
# "ghost gun" handgun
# 9 mm semi-automatic MAC-10 pistol
# Norinco 7.62 x 25 handgun
# Ruger semi-automatic firearm
# 9 mm Kel-Tec SUB2000 pistol caliber carbine
# .38-caliber Rossi revolver
# Bushmaster AR-15 semi-automatic rifle
# 9mm Llama pistol
# .223-caliber Colt Competition AR-15 with bump stock, vertical fore grip
# .223-caliber FNH FN15 AR-15 with bump stock, vertical fore grip
# .223-caliber FNH FN15 AR-15 with bump stock, vertical fore grip, EOTech optic
# .223-caliber Daniel Defense M4A1 AR-15 with bump stock, vertical fore grip, EOTech optic
# .223-caliber Daniel Defense DDM4V11 AR-15 with bump stock, vertical fore grip, EOTech optic
# .223-caliber Colt M4 carbine AR-15 with bump stock, vertical fore grip
# .223-caliber Colt M4 carbine AR-15 with bump stock, vertical fore grip, front sight
# .223-caliber Christensen Arms CA-15 AR-15 Wylde with bump stock, vertical fore grip
# .308-caliber rifle
# 7mm Browning rifle
# 9mm Walther semi-automatic pistol
# .22-caliber Ruger 10/22 rifle
# .38 Special Smith & Wesson M36 revolver
# .223-caliber Sig Sauer MCX AR-15 style semi-automatic rifle
# 9mm Walther P99 pistol
# .308-caliber FNH FM15 AR-10 with bipod, scope
# .308-caliber LMT LM308MWS AR-10 with bipod, scope
# .223-caliber LMT Def. 2000 AR-15 with bump stock, vertical fore grip
# .308-caliber LMT LM308MWS AR-10 with bipod, red dot scope
# .223-caliber LWRC M61C AR-15 with bump stock, vertical fore grip
# .223-caliber LWRC M61C AR-15 with bump stock, vertical fore grip, EOTech optic
# .223-caliber Noveske Rifleworks N4 AR-15 with bump stock, vertical fore grip, EOTech optic
# .223-caliber POF USA P15 AR-15 with bump stock, vertical fore grip
# .223-caliber POF USA P15 AR-15 with bump stock, vertical fore grip, EOTech optic
# .308-caliber POF USA P-308 AR-10 with bipod and scope
# .308-caliber Ruger American bolt-action rifle with scope
# .308-caliber Ruger SR0762 AR-10 with bipod, scope
# .308-caliber Sig Sauer SIG716 AR-10 with bipod, red dot optic
# .38-caliber Smith & Wesson 342 AirLite revolver
# .223-caliber Ruger AR-556 AR-15 style rifle
# .22-caliber Ruger SR22 pistol
# .223-caliber AR-15 semi-automatic rifle
# .22-caliber Walther P22 pistol
# 7.62mm SKS AK-47 style semi-automatic rifle
# Mossberg Maverick Arms M88 shotgun with a pistol grip
# .45-caliber Remington pistol
# 9mm Browning semi-automatic pistol
# Sentinel revolver
# 20-gauge Winchester pump-action shotgun
# .357-caliber Ruger Blackhawk revolver
# .223-caliber Ruger Mini-14 semi-automatic rifle
# .45-caliber Colt semi-automatic pistol
# .38-caliber snub-nosed revolver
# Remington 870 shotgun
# 12-gauge Smith & Wesson shotgun
# .45-caliber Colt pistol
# 9mm Browning P-35 Hi-Power pistol
# 12-gauge Winchester 1200 pump-action shotgun
# 9mm Israeli Military Industries Uzi Model A carbine
# 9mm Smith & Wesson Model 459 semi-automatic pistol
# 12-gauge Benelli Riot semi-automatic shotgun
# .22-250 rifle with scope
# Pump-action shotgun
# 7.62mm Norinco 56S AK-47 style semi-automatic rifle
# 9mm Taurus pistol
# .38-caliber snub-nose revolver
# 9mm Sig-Sauer pistol
# 7.62mm AK-47 semi-automatic rifle
# .30-caliber Univeral M1 carbine rifle
# .38-caliber Smith & Wesson Model 36 revolver
# 9mm machine pistol
# .22-caliber MAC 10 machine gun with silencer
# 9mm Uzi machine pistol
# 9mm Glock 17 semi-automatic pistol
# 9mm Ruger P89 pistol
# .38-caliber snub-nose Taurus revolver
# .357 Magnum revolver
# Large-caliber Rolling Block replica single-shot rifle
# .357 Smith & Wesson blue steel revolver
# .22-caliber rifle with stock sawed-off and pistol grip
# .308-caliber Remington rifle
# .223-caliber M-16 style semi-automatic rifle
# 5.56mm M-16 automatic rifle
# .22-caliber semi-automatic rifle
# .30-30-caliber rifle
# .44-caliber Magnum carbine rifle
# .22-caliber Marlin semi-automatic rifle
# .30-caliber Marlin carbine
# .22-caliber revolver
# .30-caliber M1 semi-automatic rifle
# .30-06 rifle
# 12-gauge Sears sawed-off shotgun
# 9mm Luger pistol
# 6.35mm Galesi-brescia pistol
# .30 M1 carbine
# .44-caliber Magnum Ruger semi-automatic carbine rifle
# .30-30 carbine rifle
# .22-caliber Marlin Model 60 semi-automatic rifle
# .223-caliber AR-15 rifle with bayonet and scope
# .30-caliber M1 carbine rifle with bayonet
# .38-caliber pistol
# .22-caliber pearl-handled pistol
# .35-caliber Marlin rifle
# 9mm Luger semi-automatic pistol
# .30 caliber M1 carbine rifle
# .30-caliber M1 carbine rifle
# .25-caliber "Excam Blue Steel" pistol
# 12-gauge Ithaca 37 pump-action shotgun
# .223-caliber Ruger Mini-14 semi-automatic rifle with collapsible stock, silencer
# .22-caliber pistol with silencer
# .357 Magnum Smith & Wesson stainless steel revolver
# .25-caliber automatic pistol
# .22-caliber Ruger sawed-off semi-automatic carbine rifle
# 12-gauge Maverick pump-action shotgun
# .30-06 Ruger bolt-action rifle
# .30-30 Marlin rifle with scope
# 12-gauge sawed-off shotgun
# Assault rifle converted to fully automatic
# AK-47 style rifle converted to fully automatic
# Remington H70 shotgun
# .38-caliber special revolver
# 7.62mm SKS 1954R rifle
# Armi Fratelli BTA90 semi-automatic pistol
# .380-caliber AMT semi-automatic pistol
# Ruger SP101 .38 Special Revolver
# .460-caliber Magnum Weatherby Mark V bolt-action rifle with scope
# .32-caliber Spanish Retolaza pistol
# AK-47 style semi-automatic rifle
# 12-gauge Winchester 1300 pump-action shotgun
# 9mm Lorcin semi-automatic pistol
# .22-caliber Magnum derringer
# .45-caliber Ruger pistol
# 9mm XD9
# .380-caliber Walther PP pistol
# Revolver
# Remington .35-caliber Model 141 pump-action rifle
# Glock pistol
# .40-caliber Glock 22 pistol
# 12-gauge Remington 870 pump-action shotgun
# .22-caliber Ruger MK II pistol
# 9mm Smith & Wesson 915 pistol
# .40-caliber Ruger P-94 pistol
# .223-caliber Bushmaster XM15 AR-15 style rifle
# 12-gauge Winchester Defender 1300 pump-action shotgun with a pistol grip
# .38-caliber Revolver
# 12-gauge Browning shotgun
# 9mm Springfield Arms semi-automatic pistol
# 9mm Ruger P85 semi-automatic pistol
# .25-caliber Raven Arms pistol
# 9mm Llama semi-automatic pistol
# .45-caliber semi-automatic pistol
# .22-caliber gun
# .32-caliber handgun
# 9mm Ruger P85 pistol
# .223-caliber Colt AR-15 rifle
# 9mm Intratec TEC-9 automatic pistol
# Ingram MAC-11 machine pistol
# 9mm CZ Model 85 pistol
# .22 Harrington & Richardson revolver
# 9mm Ruger pistol
# 7.62mm MAK-90 AK-47 style rifle
# 9mm Ruger P-89 pistol
# .300-caliber Browning rifle with scope
# .44 Magnum Smith & Wesson Classic revolver
# .45-caliber Norinco Model 1911A1 pistol
# 7.62mm AK47S semi-automatic rifle with pistol grip
# .380-caliber FIE pistol
# .30-06 Remington 742 rifle with scope
# .380-caliber Star pistol
# .30-caliber Universal M1 carbine replica rifle
# .357-caliber Ruger Security Six revolver
# .22-caliber Double Deuce Buddie two-shot derringer
# .44 Magnum Ruger rifle
# .38-caliber Davis Industries two-shot derringer
# .22-caliber Ruger semi-automatic rifle
# .22-caliber Ruger pistol
# 9mm Larson pistol
# 12 gauge Savage Springfield 67H pump-action sawed-off shotgun
# 12-gauge Savage 311D double-barreled sawed-off shotgun
# 9mm Hi-Point 995 carbine
# 9mm Intratec Tec-DC9 machine pistol
# .45-caliber Colt 1911 A-1 pistol
# 9 mm Smith and Wesson M&P Shield EZ 2.0 handgun

# %%
from data_exploration import find_keyword_in_list

search_keywords = [
    'Glock',
    'Davis Industries',
    'Charter Arms',
    'SIG Sauer',
    'Smith & Wesson',
    'Intratec',
    'Beretta',
    'Daniel Defense',
    'Ruger',
    'Springfield Armory',
    'Remington',
    'Mossberg',
    'Taurus',
    'Del-Ton',
    'Saiga',
    'HiPoint',
    'Herstal',
    'Winchester',
    'Bushmaster',
    'Century Arms',
    'Savage',
    'Romarm',
    'Norinco',
    'Saiga',
    'DPMS',
    'SKS',
    'Anderson',
    'Colt',
    'HM Defense',
    'Norinco',
    'Kel-Tec',
    'Rossi',
    'Llama',
    'FNH',
    'Walther',
    'Browning',
    'LWRC',
    'LMT',
    'POF USA',
    'Noveske Rifleworks',
    'Sentinel',
    'Israeli Military Industries',
    'Benelli',
    'Universal',
    'Marlin',
    'Sears',
    'Galesi-brescia',
    'Luger',
    'Ithaca',
    'Retolaza',
    'CZ',
    'Ingram',
    'Harrington & Richardson',
    'FIE',
    'Star',
    'Unknown'
]

makes = []

for s in search_keywords:
    makes.append(find_keyword_in_list(s, gun_names))

for i in range(len(search_keywords)):
    print(f"{search_keywords[i]}: {len(makes[i])} guns")

# Count all gund
concat_list = []

for make in makes:
    concat_list += make

print('---')
print(f"TOTAL: {len(concat_list)} guns (out of {len(gun_names)})")
# Out:
# Glock: 18 guns
# Davis Industries: 2 guns
# Charter Arms: 1 guns
# SIG Sauer: 3 guns
# Smith & Wesson: 25 guns
# Intratec: 4 guns
# Beretta: 6 guns
# Daniel Defense: 3 guns
# Ruger: 32 guns
# Springfield Armory: 2 guns
# Remington: 12 guns
# Mossberg: 5 guns
# Taurus: 4 guns
# Del-Ton: 1 guns
# Saiga: 3 guns
# HiPoint: 1 guns
# Herstal: 1 guns
# Winchester: 6 guns
# Bushmaster: 5 guns
# Century Arms: 1 guns
# Savage: 4 guns
# Romarm: 1 guns
# Norinco: 4 guns
# Saiga: 3 guns
# DPMS: 1 guns
# SKS: 3 guns
# Anderson: 1 guns
# Colt: 9 guns
# HM Defense: 1 guns
# Norinco: 4 guns
# Kel-Tec: 1 guns
# Rossi: 1 guns
# Llama: 2 guns
# FNH: 3 guns
# Walther: 4 guns
# Browning: 5 guns
# LWRC: 2 guns
# LMT: 3 guns
# POF USA: 3 guns
# Noveske Rifleworks: 1 guns
# Sentinel: 1 guns
# Israeli Military Industries: 1 guns
# Benelli: 1 guns
# Universal: 1 guns
# Marlin: 5 guns
# Sears: 1 guns
# Galesi-brescia: 1 guns
# Luger: 2 guns
# Ithaca: 1 guns
# Retolaza: 1 guns
# CZ: 1 guns
# Ingram: 1 guns
# Harrington & Richardson: 1 guns
# FIE: 1 guns
# Star: 1 guns
# Unknown: 1 guns
# ---
# TOTAL: 212 guns (out of 309)
