# %%
# Ignore all warnings
from warnings import simplefilter
simplefilter(action='ignore')

# Import dependencies
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from matplotlib import pyplot as plt

# Import the models from SKLearn (Model 1 through Model 6)
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
import pickle

# Local module
from ml_classification import model_performance

# %% [markdown]
# ## Load data

# %%
# General Population data
genpop_df = pd.read_csv(Path('model_blackbox_genpop.csv'))

# Separate the X variable, the features
X = genpop_df.drop(columns='Classification')

# Get dummies
dummies_df = pd.get_dummies(X.drop(columns=['Age']))
X = pd.concat([X['Age'], dummies_df], axis=1)

# Get features from dataset
dataset_features = X.columns

# %% [markdown]
# ## Load model

# %%
# Load model from file
with open('blackbox.model','rb') as f:
    model_1 = pickle.load(f)

# Get names of necessary features
model_features = model_1.feature_names_in_

# %% [markdown]
# ## Prepare dataset for predictions

# %%
# Create empty list to store missing features
missing_features = []

# Create empty list to store extra features
extra_features = []

# Check if the dataset is missing features
if len(dataset_features) < len(model_features):

    # Loop through model features
    for feature in model_features:
        # Check if feature is missing and add missing feature to the list
        if feature not in dataset_features:
            missing_features.append(feature)

# Check if the dataset has too many features
elif len(dataset_features) > len(model_features):

    # Loop through dataset features
    for feature in dataset_features:
        # Check if feature is missing and add missing feature to the list
        if feature not in model_features:
            extra_features.append(feature)

# If the number of features is the same, make sure they are identical
if len(dataset_features) == len(model_features):
    
    # Loop through dataset features
    for feature in dataset_features:
        # Check if feature is missing and add missing feature to the list
        if feature not in model_features:
            extra_features.append(feature)

    # Loop through model features
    for feature in model_features:
        # Check if feature is missing and add missing feature to the list
        if feature not in dataset_features:
            missing_features.append(feature)


# Add missing features to dataset with value of 0
for mf in missing_features:
    X[mf] = 0

# Drop extra features from DataSet
X = X.drop(columns=extra_features)

# %%
# Data Preparation
X = X.values

# %% [markdown]
# ## Make predictions

# %%
# Make predictions
predictions_1 = model_1.predict(X)

# Add classification to DataFrame
genpop_df['Classification'] = predictions_1

# Add probability to DataFrame
genpop_df['Probability'] = 100*model_1.predict_proba(X)[:,1]

# %%
genpop_df.loc[genpop_df['Classification']==1,:].sort_values('Probability', ascending=False)
# Out:
#       Age Gender    Race Immigrant                        Education  \
# 7058   39   Male   White        No                Bachelor's degree
# 7858   46   Male  Latinx        No                Bachelor's degree
# 3685   18   Male   White        No                Bachelor's degree
# 4881   24   Male   Asian        No                Bachelor's degree
# 4974   24   Male   White        No                Bachelor's degree
# ...   ...    ...     ...       ...                              ...
# 8775   50   Male   White        No                  High school/GED
# 178    59   Male   White        No                Bachelor's degree
# 8169   45   Male   Other       Yes                  High school/GED
# 6815   33   Male   White       Yes  Graduate school/advanced degree
# 1411   32   Male   White        No        Some college/trade school
#
#                        RelStatus     Employed          Work MilService  \
# 7058        Boyfriend/girlfriend      Working  White collar         No
# 7858        Boyfriend/girlfriend  Not Working  White collar         No
# 3685  Divorced/separated/widowed      Working  White collar         No
# 4881  Divorced/separated/widowed      Working  White collar         No
# 4974  Divorced/separated/widowed      Working  White collar         No
# ...                          ...          ...           ...        ...
# 8775        Boyfriend/girlfriend      Working   Blue collar         No
# 178   Divorced/separated/widowed  Not Working  White collar         No
# 8169  Divorced/separated/widowed      Working   Blue collar         No
# 6815  Divorced/separated/widowed  Not Working  White collar         No
# 1411  Divorced/separated/widowed  Not Working    In between         No
#
#      Arrested ParentDivorce           SES MentalIllness MentalIllnessHistory  \
# 7058      Yes   No evidence   Lower class   No evidence                  Yes
# 7858      Yes   No evidence   Lower class   No evidence                  Yes
# 3685      Yes   No evidence   Lower class           Yes          No evidence
# 4881      Yes   No evidence   Upper class   No evidence          No evidence
# 4974      Yes   No evidence   Lower class   No evidence                  Yes
# ...       ...           ...           ...           ...                  ...
# 8775       No   No evidence   Upper class   No evidence                  Yes
# 178        No   No evidence   Lower class   No evidence          No evidence
# 8169       No   No evidence   Lower class   No evidence          No evidence
# 6815       No   No evidence   Upper class   No evidence          No evidence
# 1411       No   No evidence  Middle class   No evidence                  Yes
#
#                              Autism HealthIssues  Classification  Probability
# 7058  Diagnosed or extremely likely  No evidence               1    99.979946
# 7858  Diagnosed or extremely likely  No evidence               1    99.943663
# 3685                    No evidence  No evidence               1    99.930192
# 4881                    No evidence  No evidence               1    99.877975
# 4974                    No evidence  No evidence               1    99.867040
# ...                             ...          ...             ...          ...
# 8775  Diagnosed or extremely likely  No evidence               1    50.711020
# 178                     No evidence  No evidence               1    50.654316
# 8169                    No evidence  No evidence               1    50.535135
# 6815                    No evidence  No evidence               1    50.215142
# 1411  Diagnosed or extremely likely  No evidence               1    50.197669
#
# [366 rows x 18 columns]
