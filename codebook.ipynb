# %% [markdown]
# # Codebook
# Converted from original XLSX database

# %%
import pandas as pd

# %% [markdown]
# ### Offender
# - OFFENDER BACKGROUND
# - CRIME AND VIOLENCE
# - TRAUMA AND ADVERSE CHILDHOOD EXPERIENCES
# - SIGNS OF A CRISIS
# - HEALTH AND MENTAL HEALTH
# - GRIEVANCE AND MOTIVATION
# - SOCIAL CONTAGION
# - WEAPONS
#
# ### Case
# - RESOLUTION OF CASE
# - Location
# - Victims
# - VICTIMS TAB
# - COMMUNITY TAB
#
# ### Firearm
# - FIREARMS TAB

# %% [markdown]
# ## Offender Background

# %%
Codes = {
    'background': {
        'gender': {
            '0': 'Male',
            '1': 'Female',
            '3': 'Non-Binary',
            '4': 'Transgender'
        },
        'race': {
            '0': 'White',
            '1': 'Black',
            '2': 'Latinx',
            '3': 'Asian',
            '4': 'Middle Eastern',
            '5': 'Native American'
        }
    }
}

code_offender_is_immigrant = {
    '0': False,
    '1': True
}

code_offender_is_heterosexual = {
    '0': False,
    '1': True
}

code_offender_religion = {
    '0': 'None',
    '1': 'Christian',
    '2': 'Muslim',
    '3': 'Buddhist',
    '4': 'Other',
    '5': 'Jewish'
}

code_offender_education = {
    '0': 'Less than high school',
    '1': 'High school/GED',
    '2': 'Some college/trade school',
    '3': "Bachelor's degree",
    '4': 'Graduate school/advanced degree'
}

# OFFENDER BACKGROUND / School performance
code_offender_schoolperformance = {
    '0': "Poor (D-F grades, under 2.0 GPA, failed classes, repeated grades)",
    '1': "Average (C's, 2.0-3.49 GPA)",
    '2': "Good (A-B grades, 3.5-4.0 GPA)"
}

# OFFENDER BACKGROUND / Birth order
code_offender_birthorder = {
    '0': 'Only child',
    '1': 'Oldest child',
    '2': 'Middle child',
    '3': 'Youngest child',
    '4': 'Twin'
}

code_offender_relationship = {
    '0': "Single",
    '1': "Boyfriend/girlfriend",
    '2': "Married",
    '3': "Divorced/separated/widowed"
}

# OFFENDER BACKGROUND / Children
# Shooter was a parent
# Note of Caution: original codes are "Yes" and "No evidence"
code_offender_is_parent = {
    '0': False,
    '1': True
}

# OFFENDER BACKGROUND / Exmployment status
code_offender_is_employed = {
    '0': False,
    '1': True
}

# OFFENDER BACKGROUND / Employment type
# Based on most recent employment
code_offender_employment = {
    '0': 'Blue collar',
    '1': 'White collar',
    '2': 'In between'
}

# OFFENDER BACKGROUND / Military service
code_offender_milservice = {
    '0': 'No',
    '1': 'Yes',
    '2': 'Joined but did not make it through training'
}

# OFFENDER BACKGROUND / Military branch
code_offender_milbranch = {
    '0': 'Army',
    '1': 'Navy',
    '2': 'Air Force',
    '3': 'Marines',
    '4': 'Coast Guard',
    '5': 'National Guard'
}

# OFFENDER BACKGROUND / Community involvement
# Participation in civic life and membership in local clubs and organizations
code_offender_community = {
    '0': 'No evidence',
    '1': 'Somewhat involved',
    '2': 'Heavily involved',
    '3': 'Formerly involved but recently withdrawn'
}
